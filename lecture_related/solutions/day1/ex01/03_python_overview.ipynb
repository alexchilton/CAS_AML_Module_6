# %% [markdown]
# # Shortcuts
#
# Shortcut | Command
# --- | ---
# Shift+Tab | Open Help
# Strg+Enter | Run cell
# Shift+Enter | Run cell and select next cell
# Alt+Enter | Run cell and insert cell below
# Strg+# | Convert marked lines into comments (German Keyboard)
# a | Insert cell above marked cell
# b | Insert cell below marked cell
# m | Convert cell to markdown type
# y | Convert cell to code type

# %% [markdown]
# # Datatypes

# %%
integer_name = 1

# %%
print(integer_name)
floatingpoint = 1.5

complexnumber = 1 + 1j

string1 = 'absj'
string2 = "ab'sj"
string3 = '''absj'''
string4 = """absj"""
print(string4)

print(f'Integer value: {integer_name}')
# Out:
# 1
# absj
# Integer value: 1

# %% [markdown]
# # Arithmetic operations

# %%
1 + 1
2 - 1
#2 ** 2
#10_000
#2*10e4
#1*10**4
#41/2
#40//2
# Out:
# 1

# %% [markdown]
# # Collections

# %%
# List

l = [integer_name, '123', [1, 2, 3,4 ], 1 + 1j]
print(l)
# Out:
# [1, '123', [1, 2, 3, 4], (1+1j)]

# %%
l.append(5)
l
# Out:
# [1, '123', [1, 2, 3, 4], (1+1j), 5]

# %%
m = [30, 40]
l.extend(m)
l
# Out:
# [1, '123', [1, 2, 3, 4], (1+1j), 5, 30, 40]

# %%
# Indexing and Slicing

print(l[0])
print(l[-1])
print(l[0:-1])
print(l[0:-1:2])
print(l[::2])
# Out:
# 1
# 40
# [1, '123', [1, 2, 3, 4], (1+1j), 5, 30]
# [1, [1, 2, 3, 4], 5]
# [1, [1, 2, 3, 4], 5, 40]

# %%
# Tuple
t = (1, 2, 3)
print(t)
# Out:
# (1, 2, 3)

# %%
# Collection operations (Be careful):
t2  = (9, 8, 7)
print(t + t2)
print(t * 3)
# Out:
# (1, 2, 3, 9, 8, 7)
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
# Dict

# %%
dictionary = {
    'a': 1,
    2: 'b',
    'c': 3,
}
dictionary
# Out:
# {'a': 1, 2: 'b', 'c': 3}

# %%
dictionary[2]
# Out:
# 'b'

# %%
dictionary.keys()
# Out:
# dict_keys(['a', 2, 'c'])

# %%
dictionary.values()
# Out:
# dict_values([1, 'b', 3])

# %%
dictionary.items()
# Out:
# dict_items([('a', 1), (2, 'b'), ('c', 3)])

# %%
dictionary = {}

# %% [markdown]
# # Conditions

# %%
a = 6
if a <= 2:
    b = 2
elif a < 10:
    b = 3
else:
    b = 4
b
# Out:
# 3

# %%
if (a == 2) and (b == 3):
    c = 3

# %%
d = None
if a == 2 or d is None:
    if d is not None:
        c = None

# %% [markdown]
# # Loops

# %%
l = list(range(5))
l2 = []
for entry in l:
    print(entry ** 2)
    l2.append(entry ** 2)

for index in range(len(l)):
    print(l[index] ** 2)
    l2.append(l[index] ** 2)

for index, entry in enumerate(l):
    print(entry ** 2)
    l2.append(entry ** 2)

print(l2)

l
# Out:
# 0
# 1
# 4
# 9
# 16
# 0
# 1
# 4
# 9
# 16
# 0
# 1
# 4
# 9
# 16
# [0, 1, 4, 9, 16, 0, 1, 4, 9, 16, 0, 1, 4, 9, 16]
# [0, 1, 2, 3, 4]

# %% [markdown]
# # List comprehensions:

# %%
l = list(range(50))

l2 = [entry ** 2 for entry in l]
# print(l2)
l2 = [
    entry ** 2
    for entry in l
    if entry ** 2 >= 100
]
print(l2)
# Out:
# [100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936, 2025, 2116, 2209, 2304, 2401]

# %% [markdown]
# # Dict comprehensions

# %%
d2 = {
    entry: entry ** 2
    for entry in l
    if entry ** 2 >= 100
}
d2
# Out:
# {10: 100,
#  11: 121,
#  12: 144,
#  13: 169,
#  14: 196,
#  15: 225,
#  16: 256,
#  17: 289,
#  18: 324,
#  19: 361,
#  20: 400,
#  21: 441,
#  22: 484,
#  23: 529,
#  24: 576,
#  25: 625,
#  26: 676,
#  27: 729,
#  28: 784,
#  29: 841,
#  30: 900,
#  31: 961,
#  32: 1024,
#  33: 1089,
#  34: 1156,
#  35: 1225,
#  36: 1296,
#  37: 1369,
#  38: 1444,
#  39: 1521,
#  40: 1600,
#  41: 1681,
#  42: 1764,
#  43: 1849,
#  44: 1936,
#  45: 2025,
#  46: 2116,
#  47: 2209,
#  48: 2304,
#  49: 2401}

# %% [markdown]
# ## Collections exercise

# %% [markdown]
# Create a list of 10 elements consisting of the first 10 alphabet letters

# %%
### BEGIN SOLUTION
l = [l for l in 'abcdefghij']
l
### END SOLUTION
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %% [markdown]
# Create another list that contains the 10 elements from above in reversed order

# %%
### BEGIN SOLUTION
l_rev = list(reversed(l))
l_rev
### END SOLUTION
# Out:
# ['j', 'i', 'h', 'g', 'f', 'e', 'd', 'c', 'b', 'a']

# %% [markdown]
# Create a dictionary with two key-value pairs.
# First key 'A' contains the first list with 10 alphabet letters in correct order, and second key 'B' contains the second list with the reversed order letters.

# %%
### BEGIN SOLUTION
alph_d = {'A': l, 'B': l_rev}
alph_d
### END SOLUTION
# Out:
# {'A': ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'],
#  'B': ['j', 'i', 'h', 'g', 'f', 'e', 'd', 'c', 'b', 'a']}

# %% [markdown]
# Create three tuples of size 1 and add them to a list. Each tuple shall contain a dictionary with 5 keys that are enumerated integers and the corresponding values are these integers times ten.
# Each tuple's dictionary is continuing the enumeration of the previous dictionary.
# Print each key and value pair by iterating through the list.

# %%
### BEGIN SOLUTION
res = []
for i in range(1, 4):
    start, end = (i-1)*5, i*5
    d = {idx: 10*idx for idx in range(start, end)}
    res.append((d,))
for r in res:
    for k, v in r[0].items():
        print(f'key {k}: value {v}')
### END SOLUTION
# Out:
# key 0: value 0
# key 1: value 10
# key 2: value 20
# key 3: value 30
# key 4: value 40
# key 5: value 50
# key 6: value 60
# key 7: value 70
# key 8: value 80
# key 9: value 90
# key 10: value 100
# key 11: value 110
# key 12: value 120
# key 13: value 130
# key 14: value 140

# %% [markdown]
# # Functions

# %%
def sub(a_val, b_val):
    """Calculate a - b"""
    return a_val - b_val

a = 2
b = 1

print(sub(a, b))
print(sub(b, a))
print(sub(b_val=b, a_val=a))
print(sub(a_val=a, b_val=b))
# Out:
# 1
# -1
# 1
# 1

# %% [markdown]
# # Classes

# %%
class Dog:
    """Represents a dog."""
    def __init__(self, name):
        self.name = name

    def sit(self):
        print(self.name, 'is sitting.')

dog = Dog('Lucky')

# %%
dog.sit()
# Out:
# Lucky is sitting.

# %% [markdown]
# ## Function and Classes exercise
# Write a class `Cat` with an init function that takes `breed` as argument and sets the same attribute.
#
# If the `breed` argument is neither 'Balinese' nor 'Bengal', an error statement is to be printed.
#
# Give the cat a function `pet()`: If the cat is balinese, print 'meow', if the cat is bengal, print 'purr'.

# %%
### BEGIN SOLUTION
class Cat:

    def __init__(self, breed):
        assert breed in ['Balinese', 'Bengal'], 'breed not understood'
        self.breed = breed

    def pet(self):
        if self.breed == 'Balinese':
            print('meow')
        elif self.breed == 'Bengal':
            print('purr')
        else:
            print('??')
### END SOLUTION

# %% [markdown]
# Create a class `CrazyCatLady` which initializes without arguments an attribute `cats`, which is a list of 10 balinese and 5 bengal cats.
#
# Create a class-function `throw`, which removes one cat from her set of cats.
#
# Create a class-function `talk_to_cats`, which returns a dictionary of her remaining cats with keys being random names and values being the corresponding cat.

# %%
import random
### BEGIN SOLUTION
class CrazyCatLady:

    cat_names = ['Oscar', 'Max', 'Tiger', 'Sam', 'Misty', 'Simba',
                 'Coco'	, 'Chloe', 'Lucy' ,  'Missy', 'Molly', 'Tigger',
                 'Smokey', 'Milo', 'Cleo']

    def __init__(self):
        self.cats = 10*[Cat('Balinese')] + 5*[Cat('Bengal')]

    def throw(self):
        self.cats.pop()

    def talk_to_cats(self):
       return {n: cat for n, cat in zip(random.choices(self.cat_names, k=len(self.cats)), self.cats)}

### END SOLUTION
ccl = CrazyCatLady()
ccl.throw()
ccl.throw()
ccl.throw()
ccl.throw()
print(ccl.talk_to_cats())
ccl.throw()
ccl.throw()
ccl.throw()
ccl.talk_to_cats()
# Out:
# {'Simba': <__main__.Cat object at 0x7c048a7d9610>, 'Coco': <__main__.Cat object at 0x7c048a7d9610>, 'Tigger': <__main__.Cat object at 0x7c048a7d9610>, 'Molly': <__main__.Cat object at 0x7c048a7d8c50>, 'Milo': <__main__.Cat object at 0x7c048a7d9610>, 'Missy': <__main__.Cat object at 0x7c048a7d9610>, 'Tiger': <__main__.Cat object at 0x7c048a7d9610>, 'Cleo': <__main__.Cat object at 0x7c048a7d9610>}
# {'Simba': <__main__.Cat at 0x7c048a7d9610>,
#  'Milo': <__main__.Cat at 0x7c048a7d9610>,
#  'Coco': <__main__.Cat at 0x7c048a7d9610>,
#  'Lucy': <__main__.Cat at 0x7c048a7d9610>,
#  'Molly': <__main__.Cat at 0x7c048a7d9610>,
#  'Smokey': <__main__.Cat at 0x7c048a7d9610>,
#  'Oscar': <__main__.Cat at 0x7c048a7d9610>}

# %% [markdown]
# # Outlook numerical computing
#
# Matrix Multiplication.
# Program the multiplication of the matrices with `for` loops:

# %%
A = [
    [1, 2, 3],
    [4, 5, 6],
]
B = [
    [7, 8],
    [9, 10],
    [11, 12],
]
C = [
    [0, 0],
    [0, 0],
]

# C = A * B
for i, a_ in enumerate(A):
    for a, b_ in zip(a_, B):
        for j, b in enumerate(b_):
            C[i][j] += a * b

C
# Out:
# [[58, 64], [139, 154]]

# %%
import numpy as np
np.matmul(A, B)
# Out:
# array([[ 58,  64],
#        [139, 154]])
