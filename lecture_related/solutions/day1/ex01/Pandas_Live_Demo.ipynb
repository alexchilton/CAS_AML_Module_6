# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("default")
import seaborn as sns

# %%
plt.figure()
plt.plot(np.arange(100)**2)
plt.show()

# %%
data = np.array([[2, 3, 4, 5],
                 [6, 7, 8, 9]])
data.shape
# Out:
# (2, 4)

# %%
df = pd.DataFrame(data, columns=['a', 'b', 'c', 'd'], index=['Erster_Eintrag', 'Zweiter_Eintrag'])
df
# Out:
#                  a  b  c  d
# Erster_Eintrag   2  3  4  5
# Zweiter_Eintrag  6  7  8  9

# %%
df.values
# Out:
# array([[2, 3, 4, 5],
#        [6, 7, 8, 9]])

# %%
# Komplette Spalte
df['a']
# Out:
# Erster_Eintrag     2
# Zweiter_Eintrag    6
# Name: a, dtype: int64

# %%
data[:, 0]
# Out:
# array([2, 6])

# %%
df.iloc[:, 0:3]
# Out:
#                  a  b  c
# Erster_Eintrag   2  3  4
# Zweiter_Eintrag  6  7  8

# %%
df.loc[:, ['a', 'b']]
# Out:
#                  a  b
# Erster_Eintrag   2  3
# Zweiter_Eintrag  6  7

# %%
data = np.random.randn(1000, 2)
data[:, 1] = data[:, 1]*2 + 1
df = pd.DataFrame(data, columns=['X1', 'X2'])
df.head()
# Out:
#          X1        X2
# 0  1.069336  4.285150
# 1 -0.090104  1.223044
# 2  0.290270  1.807417
# 3  2.272190  0.844113
# 4  1.352112 -2.928992

# %%
plt.figure()
plt.scatter(df['X1'], df.X2)
plt.xlabel('X1')
plt.ylabel('X2')
# Out:
# Text(0, 0.5, 'X2')

# %%
sns.jointplot(x='X1', y='X2', data=df, kind='kde')

# %%
df.corr()
# Out:
#           X1        X2
# X1  1.000000 -0.000824
# X2 -0.000824  1.000000

# %%
df['X3'] = df['X1'] + 0.5*df['X2']

# %%
sns.jointplot(x='X1', y='X3', data=df, kind='kde')

# %%
df.corr()
# Out:
#           X1        X2        X3
# X1  1.000000 -0.000824  0.702495
# X2 -0.000824  1.000000  0.711109
# X3  0.702495  0.711109  1.000000

# %%
df.head()
# Out:
#          X1        X2        X3
# 0  1.069336  4.285150  3.211910
# 1 -0.090104  1.223044  0.521418
# 2  0.290270  1.807417  1.193979
# 3  2.272190  0.844113  2.694247
# 4  1.352112 -2.928992 -0.112383

# %%
for column in df.columns:
    my_column = df[column]
    print(f'{column}: Summe {np.mean(my_column)}')
# Out:
# X1: Summe 0.04560658354996503
# X2: Summe 1.0125828753627784
# X3: Summe 0.5518980212313542

# %%
df.mean(axis=0)
# Out:
# X1    0.045607
# X2    1.012583
# X3    0.551898
# dtype: float64

# %%
 df.mean(axis=1)
# Out:
# 0      2.855465
# 1      0.551453
# 2      1.097222
# 3      1.936850
# 4     -0.563088
#          ...
# 995    0.627400
# 996    0.765330
# 997   -0.472856
# 998   -0.727308
# 999    0.806200
# Length: 1000, dtype: float64
